# %%
# !pip install pyautogui pillow flask opencv-python
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...

# %%
import pyautogui
import io
print(pyautogui.size())  # Should print screen resolution
# Out:
# Size(width=1920, height=1200)

# %%
def BeamToggle():
    pyautogui.moveTo(1828, 1107, duration=0.5)
    pyautogui.sleep(2)
    pyautogui.click()
    pyautogui.click()

# %%
BeamToggle()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 beamToggle()
#
# NameError: name 'beamToggle' is not defined

# %%
img = pyautogui.screenshot()
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1200>
